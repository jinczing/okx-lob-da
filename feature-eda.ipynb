# %%
import pandas as pd

# %%
books = pd.read_csv('./target/okx_features.csv')

# %%
books.shape
# Out:
# (86400, 25)

# %%
books.head()
# Out:
#        timestamp                  iso_time           vwap  buy_volume  \
# 0  1759276800000  2025-10-01T00:00:00.000Z  114062.278645    0.000112
# 1  1759276801000  2025-10-01T00:00:01.000Z  114049.324630    1.833670
# 2  1759276802000  2025-10-01T00:00:02.000Z  114067.825621    0.093855
# 3  1759276803000  2025-10-01T00:00:03.000Z  114066.668078    0.019652
# 4  1759276804000  2025-10-01T00:00:04.000Z  114062.107696    0.001358
#
#    sell_volume  ask_size_1  ask_size_2  ask_size_3  ask_size_4  ask_size_5  \
# 0     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 1     0.000086    0.250000    0.001807    0.000163    0.000017    0.000010
# 2     0.051521    0.191341    0.010003    0.001806    0.000021    0.009457
# 3     0.030516    1.776695    0.132400    0.323401    0.100000    0.100000
# 4     0.235994    0.590769    0.032400    0.054986    0.032400    0.032400
#
#    ...  bid_size_1  bid_size_2  bid_size_3  bid_size_4  bid_size_5  \
# 0  ...    0.000000    0.000000    0.000000    0.000000    0.000000
# 1  ...    1.143126    0.000845    0.030865    0.032400    0.058937
# 2  ...    1.437808    0.549966    0.527676    0.032400    0.030863
# 3  ...    0.138513    0.001807    0.001000    0.027691    0.001867
# 4  ...    0.537266    0.062184    0.032400    0.006051    0.027691
#
#    bid_size_6  bid_size_7  bid_size_8  bid_size_9  bid_size_10
# 0    0.000000    0.000000    0.000000    0.000000     0.000000
# 1    0.029276    0.169788    0.032400    0.069940     0.034207
# 2    0.018145    0.034207    0.000030    0.237046     0.066638
# 3    0.034207    0.027979    0.037203    0.001807     0.001000
# 4    0.062245    0.066638    0.034207    0.032400     0.001807
#
# [5 rows x 25 columns]

# %%
books.bid_size_
# Out:
# 0         0.000000
# 1         0.000000
# 2         0.000000
# 3         0.000000
# 4         0.000000
#             ...
# 115195    0.799122
# 115196    0.740944
# 115197    0.223224
# 115198    0.306898
# 115199    0.218500
# Name: bid_size_1, Length: 115200, dtype: float64

# %%
books.tail()
# Out:
#       instrument             ts                 timestamp  bid_size_1  \
# 86395   BTC-USDT  1759363195000  2025-10-01T23:59:55.000Z    0.799122
# 86396   BTC-USDT  1759363196000  2025-10-01T23:59:56.000Z    0.740944
# 86397   BTC-USDT  1759363197000  2025-10-01T23:59:57.000Z    0.223224
# 86398   BTC-USDT  1759363198000  2025-10-01T23:59:58.000Z    0.306898
# 86399   BTC-USDT  1759363199000  2025-10-01T23:59:59.000Z    0.218500
#
#        bid_size_2  bid_size_3  bid_size_4  bid_size_5  bid_size_6  bid_size_7  \
# 86395    0.058224    0.032400    0.022702    0.084340    0.022240    0.032400
# 86396    0.032400    0.346649    0.026767    0.009482    0.234827    0.032400
# 86397    0.004213    0.032400    0.032400    0.012000    0.012010    0.116710
# 86398    0.032400    0.048083    0.032400    0.012000    0.116710    0.000822
# 86399    0.032400    0.004213    0.032400    0.012000    0.116710    0.000822
#
#        ...  ask_size_4  ask_size_5  ask_size_6  ask_size_7  ask_size_8  \
# 86395  ...    0.001686    0.000010    0.013650    0.041852    0.000100
# 86396  ...    0.000010    0.010189    0.000010    0.013640    0.004199
# 86397  ...    0.035225    0.013640    0.000067    0.004199    0.000414
# 86398  ...    0.036676    0.042684    0.110000    0.035225    0.013640
# 86399  ...    0.033620    0.110000    0.036676    0.042684    0.110000
#
#        ask_size_9  ask_size_10       vwap  buy_volume  sell_volume
# 86395    0.009872     0.000010  118569.65         0.0          0.0
# 86396    0.000414     0.013640  118605.65         0.0          0.0
# 86397    0.000218     0.013640  118607.65         0.0          0.0
# 86398    0.000067     0.004199  118607.65         0.0          0.0
# 86399    0.013640     0.000067  118607.65         0.0          0.0
#
# [5 rows x 26 columns]

# %%
books.buy_volume[-1000:].plot()
# Out:
# <Axes: >

# %%
books.vwap[-1000:].plot()
# Out:
# <Axes: >

# %%
books.buy_volume[-10000:].plot()
# Out:
# <Axes: >

# %%
books.iloc[:1000, 3:53].mean().plot()
# Out:
# <Axes: >

# %%
books.iloc[:1000, 53:103].mean().plot()
# Out:
# <Axes: >

# %%
books.shape
# Out:
# (86400, 108)

# %%
books.vwap[:10].plot()
# Out:
# <Axes: >

# %%
books.vwap[60:1000].plot()
# Out:
# <Axes: >

# %%
books.buy_volume.plot()
# Out:
# <Axes: >
