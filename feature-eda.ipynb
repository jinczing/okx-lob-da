# %%
import pandas as pd

# %%
books = pd.read_csv('features.csv')

# %%
books.head()
# Out:
#   instrument             ts                 timestamp  bid_size_1  bid_size_2  \
# 0   BTC-USDT  1759276800002  2025-10-01T00:00:00.002Z    0.799909    0.168400
# 1   BTC-USDT  1759276801002  2025-10-01T00:00:01.002Z    1.143126    0.000845
# 2   BTC-USDT  1759276802002  2025-10-01T00:00:02.002Z    1.437808    0.549966
# 3   BTC-USDT  1759276803002  2025-10-01T00:00:03.002Z    0.138513    0.001807
# 4   BTC-USDT  1759276804002  2025-10-01T00:00:04.002Z    0.537266    0.062184
#
#    bid_size_3  bid_size_4  bid_size_5  bid_size_6  bid_size_7  ...  \
# 0    0.021891    0.067282    0.036000    0.043824    0.000846  ...
# 1    0.030865    0.032400    0.058937    0.029276    0.169788  ...
# 2    0.527676    0.032400    0.030863    0.018145    0.034207  ...
# 3    0.001000    0.027691    0.001867    0.034207    0.027979  ...
# 4    0.032400    0.006051    0.027691    0.062245    0.066638  ...
#
#    ask_size_46  ask_size_47  ask_size_48  ask_size_49  ask_size_50  \
# 0     0.526966     0.001962     0.000090     0.002267     0.000300
# 1     0.000010     0.001191     0.001840     0.000010     0.000018
# 2     0.000377     0.000018     0.000012     0.052859     0.000010
# 3     0.000424     0.000058     0.008766     0.001807     0.066638
# 4     0.008766     0.001807     0.066638     0.000010     0.004382
#
#             vwap  buy_volume  sell_volume  total_bid_volume  total_ask_volume
# 0  113804.793849  798.968175   780.950254         58.558232         33.424606
# 1  114049.323708    1.833670     0.000086         65.113017         25.467603
# 2  114067.813989    0.093855     0.051521         63.048728         24.385083
# 3  114066.634371    0.019652     0.030516         56.403120         31.696872
# 4  114062.100572    0.001358     0.235994         64.391412         30.441961
#
# [5 rows x 108 columns]

# %%
books.iloc[:1000, 3:53].mean().plot()
# Out:
# <Axes: >

# %%
books.iloc[:1000, 53:103].mean().plot()
# Out:
# <Axes: >

# %%
books.shape
# Out:
# (86400, 108)

# %%
books.vwap[:10].plot()
# Out:
# <Axes: >

# %%
books.vwap[60:1000].plot()
# Out:
# <Axes: >

# %%
books.buy_volume.plot()
# Out:
# <Axes: >
